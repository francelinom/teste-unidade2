# %%
# site referencia para instalação e configuração do geckodriver 
# -> https://medium.com/beelabacademy/baixando-e-configurando-o-geckodriver-no-ubuntu-dc2fe14d91c
# https://github.com/mozilla/geckodriver/releases

###################################################################################

#!pip3 install 'pymongo[srv]'
#!pip install 'pymongo[tls]'
#!pip install 'selenium'
#import dns
import time
import json
from pymongo import MongoClient
from selenium import webdriver
from bs4 import BeautifulSoup as soup

#conecção com o MongoDB Compass - nome do banco -> francelino com a coleção megaSena
cloudConn = MongoClient('mongodb+srv://francelino:brasil123@cluster0.nom7d.gcp.mongodb.net/francelino?authSource=admin&replicaSet=Cluster0-shard-0&readPreference=primary&appname=MongoDB%20Compass&ssl=true')
db = cloudConn.francelino 
tb = db['megaSena']

###################################################################################

###### Função que pega o numero do concurso desejado ######

def concurso(num):
    driver = webdriver.Firefox()
    url = 'https://www.loteriaseresultados.com.br/index.php/megasena/concurso/' + num
    driver.get(url)
    
    try:
        time.sleep(5) #tempo maior para visualizar a pagina aberta 
        body = driver.find_element_by_tag_name('body')
        html = body.get_attribute('innerHTML')
        #soupPage = soup(html, 'lxml')
        soupPage = soup(html, 'html5lib')
        spanList = soupPage.findAll('span', class_='white--text font-weight-bold')
        dataList = []
        
        for i in range(6):
            dataList.append(spanList[i].text)
            
        print(dataList)
    except:
        print('')
    
    print('Completado com sucesso...')
    driver.close()
    
concurso("1122")
# Out:
# ['26', '44', '46', '49', '55', '56']
# Completado com sucesso...

# %%
# Out:
# ['26', '44', '46', '49', '55', '56']
# Completado com sucesso...
